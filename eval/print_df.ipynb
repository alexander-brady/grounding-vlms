# %%
import pandas as pd
from pathlib import Path
from IPython.display import display, Markdown

# Directory containing the CSVs
csv_dir = Path('analysis')

# List of files you want to load
files = ['summary.csv', 'outliers.csv', 'label_accuracy.csv']

for fname in files:
    path = csv_dir / fname
    if path.exists():
        df = pd.read_csv(path)
        display(Markdown(f"### `{fname}`"))
        display(df)
    else:
        display(Markdown(f"**Warning:** `{fname}` not found in {csv_dir}"))
# Out:
# ### `summary.csv`
#            model  dataset  n_examples  accuracy  over_rate  under_rate  \
# 0        GPT-4.1  FSC-147      6073.0  0.170262   0.138646    0.691092
# 1  gemma-3-4b-it  FSC-147      6146.0  0.112919   0.373902    0.513179
#
#    mean_error        MAE   MAPE (%)  sMAPE (%)
# 0  -15.784456  18.228388  21.911506  28.640318
# 1   24.904816  61.427758  53.609235  28.127849
# ### `outliers.csv`
#      idx  idx.1  truth  result  abs_err          model  dataset
# 0    780    780   3701    1000     2701        GPT-4.1  FSC-147
# 1   6003   6003   2560       1     2559        GPT-4.1  FSC-147
# 2    731    731   2092     200     1892        GPT-4.1  FSC-147
# 3   5549   5549   1231     228     1003        GPT-4.1  FSC-147
# 4   5314   5314   1400     570      830        GPT-4.1  FSC-147
# 5   2020   2020    885     150      735        GPT-4.1  FSC-147
# 6   5668   5668    949     300      649        GPT-4.1  FSC-147
# 7   1093   1093    356    1000      644        GPT-4.1  FSC-147
# 8   2238   2238    907    1540      633        GPT-4.1  FSC-147
# 9   2678   2678    953     320      633        GPT-4.1  FSC-147
# 10  3415   3415    142  238130   237988  gemma-3-4b-it  FSC-147
# 11   780    780   3701     336     3365  gemma-3-4b-it  FSC-147
# 12    61     61    423    3000     2577  gemma-3-4b-it  FSC-147
# 13   731    731   2092     225     1867  gemma-3-4b-it  FSC-147
# 14  1176   1176   1912      54     1858  gemma-3-4b-it  FSC-147
# 15  6003   6003   2560    1000     1560  gemma-3-4b-it  FSC-147
# 16  5314   5314   1400     152     1248  gemma-3-4b-it  FSC-147
# 17  1184   1184   1283      86     1197  gemma-3-4b-it  FSC-147
# 18  5146   5146    437    1499     1062  gemma-3-4b-it  FSC-147
# 19  5549   5549   1231     180     1051  gemma-3-4b-it  FSC-147
# ### `label_accuracy.csv`
#                   label  accuracy   rank          model  dataset
# 0              lighters  1.000000    top        GPT-4.1  FSC-147
# 1                screws  1.000000    top        GPT-4.1  FSC-147
# 2      birthday candles  0.666667    top        GPT-4.1  FSC-147
# 3          meat skewers  0.666667    top        GPT-4.1  FSC-147
# 4         oyster shells  0.666667    top        GPT-4.1  FSC-147
# 5                  buns  0.600000    top        GPT-4.1  FSC-147
# 6    chewing gum pieces  0.600000    top        GPT-4.1  FSC-147
# 7           bread rolls  0.589928    top        GPT-4.1  FSC-147
# 8        calamari rings  0.500000    top        GPT-4.1  FSC-147
# 9               crayons  0.500000    top        GPT-4.1  FSC-147
# 10                 bees  0.000000  worst        GPT-4.1  FSC-147
# 11              bottles  0.000000  worst        GPT-4.1  FSC-147
# 12            buffaloes  0.000000  worst        GPT-4.1  FSC-147
# 13           cartridges  0.000000  worst        GPT-4.1  FSC-147
# 14                 cows  0.000000  worst        GPT-4.1  FSC-147
# 15                deers  0.000000  worst        GPT-4.1  FSC-147
# 16            fresh cut  0.000000  worst        GPT-4.1  FSC-147
# 17              go game  0.000000  worst        GPT-4.1  FSC-147
# 18       kitchen towels  0.000000  worst        GPT-4.1  FSC-147
# 19         milk cartons  0.000000  worst        GPT-4.1  FSC-147
# 20              bottles  1.000000    top  gemma-3-4b-it  FSC-147
# 21               screws  1.000000    top  gemma-3-4b-it  FSC-147
# 22         cupcake tray  0.632000    top  gemma-3-4b-it  FSC-147
# 23       calamari rings  0.500000    top  gemma-3-4b-it  FSC-147
# 24           sea shells  0.500000    top  gemma-3-4b-it  FSC-147
# 25          donuts tray  0.424658    top  gemma-3-4b-it  FSC-147
# 26             sausages  0.400000    top  gemma-3-4b-it  FSC-147
# 27            gemstones  0.375000    top  gemma-3-4b-it  FSC-147
# 28            chopstick  0.333333    top  gemma-3-4b-it  FSC-147
# 29      instant noodles  0.333333    top  gemma-3-4b-it  FSC-147
# 30              bananas  0.000000  worst  gemma-3-4b-it  FSC-147
# 31                 bees  0.000000  worst  gemma-3-4b-it  FSC-147
# 32     birthday candles  0.000000  worst  gemma-3-4b-it  FSC-147
# 33                bowls  0.000000  worst  gemma-3-4b-it  FSC-147
# 34               camels  0.000000  worst  gemma-3-4b-it  FSC-147
# 35         candy pieces  0.000000  worst  gemma-3-4b-it  FSC-147
# 36  carrom board pieces  0.000000  worst  gemma-3-4b-it  FSC-147
# 37           cartridges  0.000000  worst  gemma-3-4b-it  FSC-147
# 38          cement bags  0.000000  worst  gemma-3-4b-it  FSC-147
# 39              cereals  0.000000  worst  gemma-3-4b-it  FSC-147
